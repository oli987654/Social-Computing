# %% [markdown]
# ## Social Computing: Notebook 2
# # Using APIs

# %% [markdown]
# Please inlcude your names below and edit the name of the file to include the last names of the people answering

# %%
# Students: Oliver Hliddal, Julian Bolfing

# %%
import requests
import json
import os
import time

# %% [markdown]
# ### 1. Google books (20 points total)
# #### Setting the request URL parameters
# You can set the parameters of the API request according to the documentation below. The first part of the request is always the same, and the "q" which stands for question will take various parameters. <br>
# More documentation can be found at: https://developers.google.com/books/docs/v1/using?hl=vi#ids
#
# <img width="50%" src=" data:image/png;base64,..."> </img>

# %% [markdown]
# **Example**: `https://www.googleapis.com/books/v1/volumes?q=isbn:0060529709` returns information about the book with the given ISBN number (Everything is illuminated by Jonathan Safran Foer).

# %% [markdown]
# **Exercise 1.1 (6 points)**
#
# Using the above parameters create the following request URLs!
#     1. Requesting books that have "potter" in the title
#     2. Requesting books that have "doyle" as author
#     3. With isbn "1904633684"
#     4. With id "2bGdK8CRKoEC"
#     5. Second result page when searching books that has "detective" listed in the category list
#     6. Second result page when searching books that have "potter in the title but showing 40 results in one page, not 10.
# <br>
#
# Try and see whether they work with `requests.get()`!

# %%
result_A = 'https://www.googleapis.com/books/v1/volumes?q=intitle:potter'
result_B = 'https://www.googleapis.com/books/v1/volumes?q=inauthor:doyle'
result_C = 'https://www.googleapis.com/books/v1/volumes?q=isbn:1904633684'
result_D = 'https://www.googleapis.com/books/v1/volumes?q=id:2bGdK8CRKoEC'
result_E = 'https://www.googleapis.com/books/v1/volumes?q=categories:detective&startIndex=10'
result_F = 'https://www.googleapis.com/books/v1/volumes?q=intitle:potter&maxResults=40&startIndex=40'

# %%
#check with requests
print(requests.get(result_A).text)
print(requests.get(result_B).text)
print(requests.get(result_C).text)
print(requests.get(result_D).text)
print(requests.get(result_E).text)
print(requests.get(result_F).text)

#continue to check all your URLs this way!
# Out:
# {
#   "kind": "books#volumes",
#   "totalItems": 200,
#   "items": [
#     {
#       "kind": "books#volume",
#       "id": "XvApAQAAMAAJ",
#       "etag": "8+cptsgoW6M",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/XvApAQAAMAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter und der Stein der Weisen",
#         "authors": [
#           "Joanne K. Rowling"
#         ],
#         "publisher": "Carlsen Verlag GmbH",
#         "publishedDate": "1998",
#         "description": "Eigentlich hatte Harry geglaubt, er sei ein ganz normaler Junge. Zumindest bis zu seinem elften Geburtstag. Da erfährt er, dass er sich an der Schule für Hexerei und Zauberei einfinden soll. Und warum? Weil Harry ein Zauberer ist. Und so wird für Harry das erste Jahr in der Schule das spannendste, aufregendste und lustigste in seinem Leben. Er stürzt von einem Abenteuer in die nächste ungeheuerliche Geschichte, muss gegen Bestien, Mitschüler und Fabelwesen kämpfen. Da ist es gut, dass er schon Freunde gefunden hat, die ihm im Kampf gegen die dunklen Mächte zur Seite stehen.\"",
#         "industryIdentifiers": [
#           {
#             "type": "OTHER",
#             "identifier": "UOM:39076002631195"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 346,
#         "printType": "BOOK",
#         "categories": [
#           "Children's literature, English"
#         ],
#         "averageRating": 5,
#         "ratingsCount": 2,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.3.1.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=XvApAQAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=XvApAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=XvApAQAAMAAJ&dq=intitle:potter&hl=&cd=1&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=XvApAQAAMAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_und_der_Stein_der_Weisen.html?hl=&id=XvApAQAAMAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=XvApAQAAMAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "Eigentlich hatte Harry geglaubt, er sei ein ganz normaler Junge."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "7EkcswEACAAJ",
#       "etag": "odC++1lv3Ec",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/7EkcswEACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter 1 und der Stein der Weisen. Schmuckausgabe",
#         "authors": [
#           "Joanne K. Rowling"
#         ],
#         "publishedDate": "2015-10-06",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3551559015"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551559012"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 245,
#         "printType": "BOOK",
#         "categories": [
#           "Juvenile Fiction"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=7EkcswEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=7EkcswEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=7EkcswEACAAJ&dq=intitle:potter&hl=&cd=2&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=7EkcswEACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_1_und_der_Stein_der_Weisen.html?hl=&id=7EkcswEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=7EkcswEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "An seinem elften Geburtstag ändert sich Harry Potters Leben für immer ."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "MEdmDwAAQBAJ",
#       "etag": "uK/MtzeXQZc",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/MEdmDwAAQBAJ",
#       "volumeInfo": {
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551557414"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "3551557411"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.4.0.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=MEdmDwAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=MEdmDwAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=MEdmDwAAQBAJ&dq=intitle:potter&hl=&cd=3&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=MEdmDwAAQBAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/_.html?hl=&id=MEdmDwAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=MEdmDwAAQBAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "4kdmDwAAQBAJ",
#       "etag": "N4m+Mg8jky8",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/4kdmDwAAQBAJ",
#       "volumeInfo": {
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551557438"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "3551557438"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.3.0.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=4kdmDwAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=4kdmDwAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=4kdmDwAAQBAJ&dq=intitle:potter&hl=&cd=4&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=4kdmDwAAQBAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/_.html?hl=&id=4kdmDwAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=4kdmDwAAQBAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "ntv6PQAACAAJ",
#       "etag": "VDb1R7FK9ZY",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/ntv6PQAACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter und der Feuerkelch",
#         "authors": [
#           "Joanne K. Rowling"
#         ],
#         "publisher": "Carlsen Verlag GmbH",
#         "publishedDate": "2008",
#         "description": "The fourth book in the Harry Potter series translated into German.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3551354049"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551354044"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 766,
#         "printType": "BOOK",
#         "categories": [
#           "England"
#         ],
#         "averageRating": 5,
#         "ratingsCount": 1,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=ntv6PQAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=ntv6PQAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=ntv6PQAACAAJ&dq=intitle:potter&hl=&cd=5&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=ntv6PQAACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_und_der_Feuerkelch.html?hl=&id=ntv6PQAACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=ntv6PQAACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "The fourth book in the Harry Potter series translated into German."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "L8kwjgEACAAJ",
#       "etag": "dmm8VIt08dg",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/L8kwjgEACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter Colouring Book",
#         "publishedDate": "2016-03",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "1783705485"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9781783705481"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 96,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=L8kwjgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=L8kwjgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=L8kwjgEACAAJ&dq=intitle:potter&hl=&cd=6&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=L8kwjgEACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_Colouring_Book.html?hl=&id=L8kwjgEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=L8kwjgEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "TZ52tgEACAAJ",
#       "etag": "w1U1YrsZtn0",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/TZ52tgEACAAJ",
#       "volumeInfo": {
#         "title": "Aus den Filmen zu Harry Potter: Die Karte des Rumtreibers - Eine Reise durch Hogwarts",
#         "publishedDate": "2018-08-27",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3833236507"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783833236501"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 64,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=TZ52tgEACAAJ&dq=intitle:potter&hl=&cd=7&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=TZ52tgEACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Aus_den_Filmen_zu_Harry_Potter_Die_Karte.html?hl=&id=TZ52tgEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=TZ52tgEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "L18VBQAAQBAJ",
#       "etag": "NrGwtiAKa6M",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/L18VBQAAQBAJ",
#       "volumeInfo": {
#         "title": "The Psychology of Harry Potter",
#         "subtitle": "An Unauthorized Examination Of The Boy Who Lived",
#         "authors": [
#           "Neil Mulholland"
#         ],
#         "publisher": "BenBella Books",
#         "publishedDate": "2007-04-10",
#         "description": "Harry Potter has provided a portal to the wizarding world for millions of readers, but an examination of Harry, his friends and his enemies will take us on yet another journey: through the psyche of the Muggle (and wizard!) mind. The twists and turns of the series, as well as the psychological depth and complexity of J. K. Rowling’s characters, have kept fans enthralled with and puzzling over the many mysteries that permeate Hogwarts and beyond: • Do the Harry Potter books encourage disobedience? • Why is everyone so fascinated by Professor Lupin? • What exactly will Harry and his friends do when they finally pass those N.E.W.T.s? • Do even wizards live by the ticking of the clock? • Is Harry destined to end up alone? And why did it take Ron and Hermione so long to get together? Now, in The Psychology of Harry Potter, leading psychologists delve into the ultimate Chamber of Secrets, analyzing human mind and motivation by examining the themes and characters that make the Harry Potter books the bestselling fantasy series of all time. Grab a spot on the nearest couch, and settle in for some fresh revelations about our favorite young wizard!",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781932100884"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1932100881"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 338,
#         "printType": "BOOK",
#         "categories": [
#           "Literary Criticism"
#         ],
#         "averageRating": 3.5,
#         "ratingsCount": 5,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.1.2.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=L18VBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=L18VBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=L18VBQAAQBAJ&printsec=frontcover&dq=intitle:potter&hl=&cd=8&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=L18VBQAAQBAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/The_Psychology_of_Harry_Potter.html?hl=&id=L18VBQAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=L18VBQAAQBAJ&hl=&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "Now, in The Psychology of Harry Potter, leading psychologists delve into the ultimate Chamber of Secrets, analyzing human mind and motivation by examining the themes and characters that make the Harry Potter books the bestselling fantasy ..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "lJB5DwAAQBAJ",
#       "etag": "x/2BZbsfcxI",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/lJB5DwAAQBAJ",
#       "volumeInfo": {
#         "title": "The Ultimate Harry Potter and Philosophy",
#         "subtitle": "Hogwarts for Muggles",
#         "authors": [
#           "William Irwin",
#           "Gregory Bassham"
#         ],
#         "publisher": "John Wiley & Sons",
#         "publishedDate": "2010-09-14",
#         "description": "A philosophical exploration of the entire seven-book Harry Potter series Harry Potter has been heralded as one of the most popular book series of all time and the philosophical nature of Harry, Hermione, and Ron's quest to rid the world of its ultimate evil is one of the many things that make this series special. The Ultimate Harry Potter and Philosophy covers all seven titles in J.K. Rowling's groundbreaking series and takes fans back to Godric's Hollow to discuss life after death, to consider what moral reasoning drove Harry to choose death, and to debate whether Sirius Black is a man or a dog. With publication timed to coincide with the release of the movie Harry Potter and the Deathly Hallows (Part 1), this book will be the definitive guide for all fans looking to appreciate the series on a deeper level. Covers a range of intriguing topics such as the redemption of Severus Snape, the power of love, and destiny in the wizarding world Gives you a new perspective on Harry Potter characters, plot lines, and themes Makes a perfect companion to the Harry Potter books and movies Packed with interesting ideas and insights, The Ultimate Harry Potter and Philosophy is an ideal companion for anyone interested in unraveling the subtext and exploring the greater issues at work in the story.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9780470398258"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "0470398256"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": true
#         },
#         "pageCount": 304,
#         "printType": "BOOK",
#         "categories": [
#           "Philosophy"
#         ],
#         "averageRating": 4.5,
#         "ratingsCount": 5,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.0.2.0.preview.1",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=lJB5DwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=lJB5DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=lJB5DwAAQBAJ&printsec=frontcover&dq=intitle:potter&hl=&cd=9&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=lJB5DwAAQBAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/The_Ultimate_Harry_Potter_and_Philosophy.html?hl=&id=lJB5DwAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.ch/books/download/The_Ultimate_Harry_Potter_and_Philosophy-sample-pdf.acsm?id=lJB5DwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=lJB5DwAAQBAJ&hl=&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "A philosophical exploration of the entire seven-book Harry Potter series Harry Potter has been heralded as one of the most popular book series of all time and the philosophical nature of Harry, Hermione, and Ron&#39;s quest to rid the world of ..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "VYodjwEACAAJ",
#       "etag": "pj4EnPOZSjg",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/VYodjwEACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter und die Heiligtümer des Todes",
#         "authors": [
#           "Joanne K. Rowling"
#         ],
#         "publishedDate": "2011",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3551354073"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551354075"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 766,
#         "printType": "BOOK",
#         "categories": [
#           "Hogwarts School of Witchcraft and Wizardry (Imaginary organization)"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=VYodjwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=VYodjwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=VYodjwEACAAJ&dq=intitle:potter&hl=&cd=10&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=VYodjwEACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_und_die_Heiligt%C3%BCmer_des_To.html?hl=&id=VYodjwEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=VYodjwEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "&quot;An eine Rückkehr nach Hogwarts ist für Harry nicht zu denken."
#       }
#     }
#   ]
# }
#
# {
#   "kind": "books#volumes",
#   "totalItems": 200,
#   "items": [
#     {
#       "kind": "books#volume",
#       "id": "C2R7DwAAQBAJ",
#       "etag": "brwn5dhoc4M",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/C2R7DwAAQBAJ",
#       "volumeInfo": {
#         "title": "Origins of the French Revolution",
#         "authors": [
#           "William Doyle"
#         ],
#         "publisher": "Oxford University Press, USA",
#         "publishedDate": "1999",
#         "description": "First published in 1980, this book rapidly established itself as the indispensable guide to what brought about the French Revolution, and to the debates of historians about the issue. It combined a full critical account of recent controversies with a fresh interpretation taking stock of wherethe debate had led. Since 1980 discussion among historians has continued as lively as ever, and has moved in directions scarcely explored at that time. The `revisionist' criticism which destroyed the classic mid-century consensus emphasizing the Revolution's social and economic origins has openedthe way to a `post-revisionist' approach focused on cultural change. This new edition brings the subject up to date with an extensisively rewritten survey of the historiography up to the present day, and a revised interpretation modified in the light of research by a new generation of scholars. It will thus remain the starting point for any serious study of thegreatest of all revolutions, which lies at the root of the modern political world. `important book . . . readable and perceptive analysis', Times Higher Education Supplement `His book is excellent, achieving the rare distinction of being both useful and revealing', Spectator `brief, clear, and thoughtful', Journal of Modern History",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9780198731740"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "0198731744"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": true
#         },
#         "pageCount": 247,
#         "printType": "BOOK",
#         "categories": [
#           "History"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=C2R7DwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=C2R7DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=C2R7DwAAQBAJ&printsec=frontcover&dq=inauthor:doyle&hl=&cd=1&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=C2R7DwAAQBAJ&dq=inauthor:doyle&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Origins_of_the_French_Revolution.html?hl=&id=C2R7DwAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.ch/books/download/Origins_of_the_French_Revolution-sample-pdf.acsm?id=C2R7DwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=C2R7DwAAQBAJ&hl=&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "First published in 1980, this book rapidly established itself as the indispensable guide to what brought about the French Revolution, and to the debates of historians about the issue."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "dAz-rphWxMYC",
#       "etag": "s6vWBJ2pO44",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/dAz-rphWxMYC",
#       "volumeInfo": {
#         "title": "Empires",
#         "authors": [
#           "Michael W. Doyle"
#         ],
#         "publisher": "Cornell University Press",
#         "publishedDate": "1986",
#         "description": "Although empires have shaped the political development of virtually all the states of the modern world, \"imperialism\" has not figured largely in the mainstream of scholarly literature. This book seeks to account for the imperial phenomenon and to establish its importance as a subject in the study of the theory of world politics. Michael Doyle believes that empires can best be defined as relationships of effective political control imposed by some political societies--those called metropoles--on other political societies--called peripheries. To build an explanation of the birth, life, and death of empires, he starts with an overview and critique of the leading theories of imperialism. Supplementing theoretical analysis with historical description, he considers episodes from the life cycles of empires from the classical and modern world, concentrating on the nineteenth-century scramble for Africa. He describes in detail the slow entanglement of the peripheral societies on the Nile and the Niger with metropolitan power, the survival of independent Ethiopia, Bismarck's manipulation of imperial diplomacy for European ends, the race for imperial possession in the 1880s, and the rapid setting of the imperial sun. Combining a sensitivity to historical detail with a judicious search for general patterns, Empires will engage the attention of social scientists in many disciplines.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "080149334X"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9780801493348"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 412,
#         "printType": "BOOK",
#         "categories": [
#           "Imperialism"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.5.5.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=dAz-rphWxMYC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=dAz-rphWxMYC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=dAz-rphWxMYC&printsec=frontcover&dq=inauthor:doyle&hl=&cd=2&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=dAz-rphWxMYC&dq=inauthor:doyle&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Empires.html?hl=&id=dAz-rphWxMYC"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=dAz-rphWxMYC&hl=&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "This book seeks to account for the imperial phenomenon and to establish its importance as a subject in the study of the theory of world politics."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "l8_yAAAAMAAJ",
#       "etag": "MpDYP5ozxb4",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/l8_yAAAAMAAJ",
#       "volumeInfo": {
#         "title": "The Commitments",
#         "authors": [
#           "Roddy Doyle"
#         ],
#         "publisher": "Vintage Books",
#         "publishedDate": "1991",
#         "description": "The Commitments is a band with a mission: bringing soul to Dublin. Led by Jimmy Rabitte, a young man with ambition, coached by Joey \"The Lips\" Fagan, an old man with a trumpet, protected by Mickah Wallace, owner of the most feared forehead in Barrytown. -- Publisher details.",
#         "industryIdentifiers": [
#           {
#             "type": "OTHER",
#             "identifier": "IND:30000038691121"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 186,
#         "printType": "BOOK",
#         "categories": [
#           "Fiction"
#         ],
#         "averageRating": 3.5,
#         "ratingsCount": 12,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.4.3.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=l8_yAAAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=l8_yAAAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=l8_yAAAAMAAJ&dq=inauthor:doyle&hl=&cd=3&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=l8_yAAAAMAAJ&dq=inauthor:doyle&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/The_Commitments.html?hl=&id=l8_yAAAAMAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=l8_yAAAAMAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "The Commitments is a band with a mission: bringing soul to Dublin."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "sD1bzgEACAAJ",
#       "etag": "05z0cXWRUKo",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/sD1bzgEACAAJ",
#       "volumeInfo": {
#         "title": "C# Programming: From Problem Analysis to Program Design",
#         "authors": [
#           "Barbara Doyle"
#         ],
#         "publisher": "Cengage Learning",
#         "publishedDate": "2015-06-30",
#         "description": "Respected author Dr. Barbara Doyle admirably balances programming principles and concepts with practical coding skill to create a strong professional foundation for beginning programmers in her latest edition of C# PROGRAMMING: FROM PROBLEM ANALYSIS TO PROGRAM DESIGN. This 5th edition’s straightforward approach and understandable vocabulary make it easy for readers to grasp new programming concepts without distraction. The book introduces a variety of fundamental programming concepts, from data types and expressions to arrays and collections, all using the latest version of today’s popular C# language. Important Notice: Media content referenced within the product description or the product text may not be available in the ebook version.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "1285856872"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9781285856872"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 0,
#         "printType": "BOOK",
#         "categories": [
#           "Computers"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=sD1bzgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=sD1bzgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=sD1bzgEACAAJ&dq=inauthor:doyle&hl=&cd=4&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=sD1bzgEACAAJ&dq=inauthor:doyle&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/C_Programming_From_Problem_Analysis_to_P.html?hl=&id=sD1bzgEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=sD1bzgEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "The book introduces a variety of fundamental programming concepts, from data types and expressions to arrays and collections, all using the latest version of today’s popular C# language."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "vf6VzQEACAAJ",
#       "etag": "8eDnqO4def0",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/vf6VzQEACAAJ",
#       "volumeInfo": {
#         "title": "The Murder Game",
#         "authors": [
#           "Carrie Doyle"
#         ],
#         "publisher": "Sourcebooks Fire",
#         "publishedDate": "2021-04-06",
#         "description": "For readers of Karen M. McManus and Maureen Johnson.Luke Chase didn't mean to get caught up solving the mystery of Mrs. Heckler's murder. He just wanted to spend alone time with the new British girl at their boarding school. But little did he know someone would end up dead right next to their rendezvous spot in the woods, and his best friend and roommate Oscar Weymouth would be the one to take the blame. With suspects aplenty and a past that's anything but innocent, Luke Chase reluctantly calls on his famous survival skills to solve the mystery and find the true killer.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "172822229X"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9781728222295"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "printType": "BOOK",
#         "averageRating": 3,
#         "ratingsCount": 1,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=vf6VzQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=vf6VzQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=vf6VzQEACAAJ&dq=inauthor:doyle&hl=&cd=5&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=vf6VzQEACAAJ&dq=inauthor:doyle&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/The_Murder_Game.html?hl=&id=vf6VzQEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=vf6VzQEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "&quot;Originally published as Sneaking out in 2018 by Dunemere Books under the pseudonym Chuck Vance&quot;--Title page verso."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "WPNIEAAAQBAJ",
#       "etag": "isyFs0NoUcE",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/WPNIEAAAQBAJ",
#       "volumeInfo": {
#         "title": "Get Untamed",
#         "subtitle": "The Journal (How to Quit Pleasing and Start Living)",
#         "authors": [
#           "Glennon Doyle"
#         ],
#         "publisher": "Clarkson Potter",
#         "publishedDate": "2021-11-16",
#         "description": "This stunning hardcover journal is a bold, interactive guide to discovering and creating the truest, most beautiful lives, families, and world we can imagine, based on the #1 New York Times bestseller Untamed. “We must stop asking people for directions to places they’ve never been. Every life is an unprecedented experiment. We are all pioneers. I created Get Untamed: The Journal as an interactive experience in charting our own way—so we can let burn that which is not true and beautiful enough and get started building what is.” —Glennon Doyle With Untamed, Glennon Doyle—writer, activist, and “patron saint of female empowerment” (People)—ignited a movement. Untamed has been described as “a wake-up call” (Tracee Ellis Ross), “an anthem for women today” (Kristen Bell), and a book that “will shake your brain and make your soul scream” (Adele). Glennon now offers a new way of journaling, one that reveals how we can stop striving to meet others’ expectations—because when we finally learn that satisfying the world is impossible, we quit pleasing and start living. Whether or not you have read Untamed, this journal leads you to rediscover, and begin to trust, your own inner-voice. Full of thought-provoking exercises, beloved quotations from Untamed, compelling illustrations, playful and meditative coloring pages, and an original introduction, in Get Untamed: The Journal, Glennon guides us through the process of examining the aspects of our lives that can make us feel caged. This revolutionary method for uprooting culturally-constructed ideas shows us how to discover for ourselves what we want to keep and what we’ll let burn so that we can build lives by design instead of default. A one-of-a-kind journal experience, Get Untamed proves Glennon’s philosophy that “imagination is not where we go to escape reality, but where we go to remember it.”",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9780593235652"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "0593235657"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 225,
#         "printType": "BOOK",
#         "categories": [
#           "Self-Help"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.2.0.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=WPNIEAAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=WPNIEAAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=WPNIEAAAQBAJ&dq=inauthor:doyle&hl=&cd=6&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=WPNIEAAAQBAJ&dq=inauthor:doyle&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Get_Untamed.html?hl=&id=WPNIEAAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
# ...
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "1643360876"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9781643360874"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 0,
#         "printType": "BOOK",
#         "categories": [
#           "Literary Criticism"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=WlLKyQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=WlLKyQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=WlLKyQEACAAJ&dq=intitle:potter&hl=&cd=75&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=WlLKyQEACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_and_Beyond.html?hl=&id=WlLKyQEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=WlLKyQEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "Along with the seven foundational novels of the Harry Potter series, Harry Potter and Beyond assesses the extraordinary range of supplementary material concerning the young wizard and his allies, including the films of the books, the ..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "oY4IzgEACAAJ",
#       "etag": "V4Bg8ddnKhs",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/oY4IzgEACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter Filmwelt",
#         "subtitle": "Bd. 11: Alles über die Lehrer von Hogwarts - Mit herausnehmbarem Kunstdruck",
#         "authors": [
#           "Jody Revenson"
#         ],
#         "publishedDate": "2021-02-23",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3833239042"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783833239045"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 64,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=oY4IzgEACAAJ&dq=intitle:potter&hl=&cd=76&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=oY4IzgEACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_Filmwelt.html?hl=&id=oY4IzgEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=oY4IzgEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "1_NPuAAACAAJ",
#       "etag": "AdTrx7CmhFQ",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/1_NPuAAACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter -- Sheet Music from the Complete Film Series",
#         "subtitle": "Big Note Piano",
#         "publisher": "Alfred Music",
#         "publishedDate": "2012-03",
#         "description": "With the Harry Potter film series now complete, Alfred Music and Warner Bros. Entertainment are proud to present big note piano arrangements from the eight epic films together in one collectible volume. For the first time ever, 36 sheet music selections by John Williams, Patrick Doyle, Nicholas Hooper, and Alexandre Desplat are collected along with eight pages of color stills from The Sorcerer's Stone to The Deathly Hallows, Part 2. By popular request, \"Leaving Hogwarts\" from The Sorcerer's Stone appears in print in this collection for the first time. It's a perfect gift for pianists of all ages who love the music of Harry Potter. Titles: Diagon Alley * Family Portrait * Harry's Wondrous World * Hedwig's Theme * Leaving Hogwarts * Nimbus 2000 * Voldemort * The Chamber of Secrets * Fawkes the Phoenix * Buckbeak's Flight * Double Trouble * Hagrid the Professor * Harry in Winter * Hogwarts March * Potter Waltz * This Is the Night * Dumbledore's Army * Fireworks * Loved Ones and Leaving * Professor Umbridge * Dumbledore's Farewell * Harry and Hermione * In Noctem * When Ginny Kissed Harry * Farewell to Dobby * Godric's Hollow Graveyard * Harry and Ginny * Obliviate * Ron Leaves * Snape to Malfoy Manor * Courtyard Apocalypse * Harry's Sacrifice * Lily's Lullaby * Lily's Theme * Severus and Lily * Statues.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "0739087711"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9780739087718"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 0,
#         "printType": "BOOK",
#         "categories": [
#           "Music"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=1_NPuAAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=1_NPuAAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=1_NPuAAACAAJ&dq=intitle:potter&hl=&cd=77&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=1_NPuAAACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_Sheet_Music_from_the_Comple.html?hl=&id=1_NPuAAACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=1_NPuAAACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "By popular request, &quot;Leaving Hogwarts&quot; from The Sorcerer&#39;s Stone appears in print in this collection for the first time. It&#39;s a perfect gift for pianists of all ages who love the music of Harry Potter."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "ZVJezgEACAAJ",
#       "etag": "dWVY+5sgMiM",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/ZVJezgEACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter Hufflepuff House Editions Hardback Box Set",
#         "authors": [
#           "J. K. Rowling"
#         ],
#         "publisher": "Bloomsbury Children's Books",
#         "publishedDate": "2021-11-11",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "1526624567"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9781526624567"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 3888,
#         "printType": "BOOK",
#         "categories": [
#           "Juvenile Fiction"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=ZVJezgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=ZVJezgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=ZVJezgEACAAJ&dq=intitle:potter&hl=&cd=78&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=ZVJezgEACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_Hufflepuff_House_Editions_H.html?hl=&id=ZVJezgEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=ZVJezgEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "The seven books in this collection are accompanied by a magical miscellany of exciting feature articles, quizzes and fascinating fact files packed with trivia about the history and alumni of Hufflepuff house - ideal to dip into and enjoy ..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "Ur5qzgEACAAJ",
#       "etag": "7XTgJ/oowOY",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/Ur5qzgEACAAJ",
#       "volumeInfo": {
#         "title": "LEGO® Harry Potter Weihnachten auf Hogwarts",
#         "subtitle": "Mit Harry Potter Minifigur!",
#         "publishedDate": "2021-09-28",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3831042276"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783831042272"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 80,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=Ur5qzgEACAAJ&dq=intitle:potter&hl=&cd=79&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=Ur5qzgEACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/LEGO_Harry_Potter_Weihnachten_auf_Hogwar.html?hl=&id=Ur5qzgEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=Ur5qzgEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "Entdecke Hogwarts zur Weihnachtszeit mit Schneeballschlachten, Winterball und einer Weihnachtsfeier im Fuchsbau von Rons Familie. Ab 7."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "DhtZmAEACAAJ",
#       "etag": "QCyo8QagaTg",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/DhtZmAEACAAJ",
#       "volumeInfo": {
#         "title": "Critical Perspectives on Harry Potter",
#         "authors": [
#           "Elizabeth E. Heilman"
#         ],
#         "publisher": "Taylor & Francis US",
#         "publishedDate": "2009",
#         "description": "Rev. ed. of: Harry Potter's world. 2003.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "0415964849"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9780415964845"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 354,
#         "printType": "BOOK",
#         "categories": [
#           "Education"
#         ],
#         "averageRating": 4,
#         "ratingsCount": 1,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=DhtZmAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=DhtZmAEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=DhtZmAEACAAJ&dq=intitle:potter&hl=&cd=80&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=DhtZmAEACAAJ&dq=intitle:potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Critical_Perspectives_on_Harry_Potter.html?hl=&id=DhtZmAEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=DhtZmAEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "Rev. ed. of: Harry Potter&#39;s world. 2003."
#       }
#     }
#   ]
# }

# %% [markdown]
# **Exercise 1.2. (14 points)**
#
# Define a function that sends a request to the google books API with the URL parameters as inputs to the function. Try to incorporate as many as the variables as possible and output a URL according to the settings you want to have. Don't forget to write a docstring explaning how the function works. Docstrings are explanations to functions, describing the input, output, and purpose of the function. If you haven't used them before, you can find more examples for example at: https://www.geeksforgeeks.org/python-docstrings/

# %%
def request_books_api(intitle="",inauthor="",inpublisher="",isbn="",lccn="",oclc="",startIndex="",maxResults="",printType="all",projection="full",orderBy="relevance",categories="",language=""):
    '''Returns api-request from google books based on parameters given.'''
    base_link="https://www.googleapis.com/books/v1/volumes?q="
    if (intitle!=""):
        base_link=base_link+"intitle:"+intitle+"&"
    if (inauthor!=""):
        base_link=base_link+"inauthor:"+inauthor+"&"
    if (inpublisher!=""):
        base_link=base_link+"inpublisher:"+inpublisher+"&"
    if (isbn!=""):
        base_link=base_link+"isbn:"+isbn+"&"
    if (lccn!=""):
        base_link=base_link+"lccn:"+lccn+"&"
    if (oclc!=""):
        base_link=base_link+"oclc:"+oclc+"&"
    if (startIndex!=""):
        base_link=base_link+"startIndex:"+startIndex+"&"
    if (maxResults!=""):
        base_link=base_link+"maxResults:"+maxResults+"&"
    if (categories!=""):
        base_link=base_link+"subject:"+categories+"&"
    if (language!=""):
        base_link=base_link+"language:"+language+"&"
    base_link=base_link+"printType:"+printType+"&"
    base_link=base_link+"projection:"+projection+"&"
    base_link=base_link+"orderBy:"+orderBy+"&"
    return requests.get(base_link)

# %%
## call your function here inside a print() statement
print(request_books_api(intitle="Potter").text)
# Out:
# {
#   "kind": "books#volumes",
#   "totalItems": 200,
#   "items": [
#     {
#       "kind": "books#volume",
#       "id": "XvApAQAAMAAJ",
#       "etag": "/GUV6VlhBpY",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/XvApAQAAMAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter und der Stein der Weisen",
#         "authors": [
#           "Joanne K. Rowling"
#         ],
#         "publisher": "Carlsen Verlag GmbH",
#         "publishedDate": "1998",
#         "description": "Eigentlich hatte Harry geglaubt, er sei ein ganz normaler Junge. Zumindest bis zu seinem elften Geburtstag. Da erfährt er, dass er sich an der Schule für Hexerei und Zauberei einfinden soll. Und warum? Weil Harry ein Zauberer ist. Und so wird für Harry das erste Jahr in der Schule das spannendste, aufregendste und lustigste in seinem Leben. Er stürzt von einem Abenteuer in die nächste ungeheuerliche Geschichte, muss gegen Bestien, Mitschüler und Fabelwesen kämpfen. Da ist es gut, dass er schon Freunde gefunden hat, die ihm im Kampf gegen die dunklen Mächte zur Seite stehen.\"",
#         "industryIdentifiers": [
#           {
#             "type": "OTHER",
#             "identifier": "UOM:39076002631195"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 346,
#         "printType": "BOOK",
#         "categories": [
#           "Children's literature, English"
#         ],
#         "averageRating": 5,
#         "ratingsCount": 2,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.3.1.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=XvApAQAAMAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=XvApAQAAMAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=XvApAQAAMAAJ&dq=intitle:Potter&hl=&cd=1&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=XvApAQAAMAAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_und_der_Stein_der_Weisen.html?hl=&id=XvApAQAAMAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=XvApAQAAMAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "Eigentlich hatte Harry geglaubt, er sei ein ganz normaler Junge."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "7EkcswEACAAJ",
#       "etag": "/i74Xe1bQbQ",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/7EkcswEACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter 1 und der Stein der Weisen. Schmuckausgabe",
#         "authors": [
#           "Joanne K. Rowling"
#         ],
#         "publishedDate": "2015-10-06",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3551559015"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551559012"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 245,
#         "printType": "BOOK",
#         "categories": [
#           "Juvenile Fiction"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=7EkcswEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=7EkcswEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=7EkcswEACAAJ&dq=intitle:Potter&hl=&cd=2&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=7EkcswEACAAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_1_und_der_Stein_der_Weisen.html?hl=&id=7EkcswEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=7EkcswEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "An seinem elften Geburtstag ändert sich Harry Potters Leben für immer ."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "MEdmDwAAQBAJ",
#       "etag": "Thrxn1+baV4",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/MEdmDwAAQBAJ",
#       "volumeInfo": {
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551557414"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "3551557411"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.4.0.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=MEdmDwAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=MEdmDwAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=MEdmDwAAQBAJ&dq=intitle:Potter&hl=&cd=3&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=MEdmDwAAQBAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/_.html?hl=&id=MEdmDwAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=MEdmDwAAQBAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "4kdmDwAAQBAJ",
#       "etag": "N/VyuZ8TIXQ",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/4kdmDwAAQBAJ",
#       "volumeInfo": {
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551557438"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "3551557438"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.3.0.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=4kdmDwAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=4kdmDwAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=4kdmDwAAQBAJ&dq=intitle:Potter&hl=&cd=4&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=4kdmDwAAQBAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/_.html?hl=&id=4kdmDwAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=4kdmDwAAQBAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "ntv6PQAACAAJ",
#       "etag": "m8Cc5q7SMkk",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/ntv6PQAACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter und der Feuerkelch",
#         "authors": [
#           "Joanne K. Rowling"
#         ],
#         "publisher": "Carlsen Verlag GmbH",
#         "publishedDate": "2008",
#         "description": "The fourth book in the Harry Potter series translated into German.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3551354049"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551354044"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 766,
#         "printType": "BOOK",
#         "categories": [
#           "England"
#         ],
#         "averageRating": 5,
#         "ratingsCount": 1,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=ntv6PQAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=ntv6PQAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=ntv6PQAACAAJ&dq=intitle:Potter&hl=&cd=5&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=ntv6PQAACAAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_und_der_Feuerkelch.html?hl=&id=ntv6PQAACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=ntv6PQAACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "The fourth book in the Harry Potter series translated into German."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "L8kwjgEACAAJ",
#       "etag": "YfebNDOroSo",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/L8kwjgEACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter Colouring Book",
#         "publishedDate": "2016-03",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "1783705485"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9781783705481"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 96,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=L8kwjgEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=L8kwjgEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=L8kwjgEACAAJ&dq=intitle:Potter&hl=&cd=6&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=L8kwjgEACAAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_Colouring_Book.html?hl=&id=L8kwjgEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=L8kwjgEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "TZ52tgEACAAJ",
#       "etag": "04ErbFgVUQA",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/TZ52tgEACAAJ",
#       "volumeInfo": {
#         "title": "Aus den Filmen zu Harry Potter: Die Karte des Rumtreibers - Eine Reise durch Hogwarts",
#         "publishedDate": "2018-08-27",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3833236507"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783833236501"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 64,
#         "printType": "BOOK",
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=TZ52tgEACAAJ&dq=intitle:Potter&hl=&cd=7&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=TZ52tgEACAAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Aus_den_Filmen_zu_Harry_Potter_Die_Karte.html?hl=&id=TZ52tgEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=TZ52tgEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "L18VBQAAQBAJ",
#       "etag": "u0Hr5aJkGZY",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/L18VBQAAQBAJ",
#       "volumeInfo": {
#         "title": "The Psychology of Harry Potter",
#         "subtitle": "An Unauthorized Examination Of The Boy Who Lived",
#         "authors": [
#           "Neil Mulholland"
#         ],
#         "publisher": "BenBella Books",
#         "publishedDate": "2007-04-10",
#         "description": "Harry Potter has provided a portal to the wizarding world for millions of readers, but an examination of Harry, his friends and his enemies will take us on yet another journey: through the psyche of the Muggle (and wizard!) mind. The twists and turns of the series, as well as the psychological depth and complexity of J. K. Rowling’s characters, have kept fans enthralled with and puzzling over the many mysteries that permeate Hogwarts and beyond: • Do the Harry Potter books encourage disobedience? • Why is everyone so fascinated by Professor Lupin? • What exactly will Harry and his friends do when they finally pass those N.E.W.T.s? • Do even wizards live by the ticking of the clock? • Is Harry destined to end up alone? And why did it take Ron and Hermione so long to get together? Now, in The Psychology of Harry Potter, leading psychologists delve into the ultimate Chamber of Secrets, analyzing human mind and motivation by examining the themes and characters that make the Harry Potter books the bestselling fantasy series of all time. Grab a spot on the nearest couch, and settle in for some fresh revelations about our favorite young wizard!",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9781932100884"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "1932100881"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 338,
#         "printType": "BOOK",
#         "categories": [
#           "Literary Criticism"
#         ],
#         "averageRating": 3.5,
#         "ratingsCount": 5,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.1.2.0.preview.0",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=L18VBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=L18VBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=L18VBQAAQBAJ&printsec=frontcover&dq=intitle:Potter&hl=&cd=8&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=L18VBQAAQBAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/The_Psychology_of_Harry_Potter.html?hl=&id=L18VBQAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=L18VBQAAQBAJ&hl=&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "Now, in The Psychology of Harry Potter, leading psychologists delve into the ultimate Chamber of Secrets, analyzing human mind and motivation by examining the themes and characters that make the Harry Potter books the bestselling fantasy ..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "lJB5DwAAQBAJ",
#       "etag": "KT8NXdop+d8",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/lJB5DwAAQBAJ",
#       "volumeInfo": {
#         "title": "The Ultimate Harry Potter and Philosophy",
#         "subtitle": "Hogwarts for Muggles",
#         "authors": [
#           "William Irwin",
#           "Gregory Bassham"
#         ],
#         "publisher": "John Wiley & Sons",
#         "publishedDate": "2010-09-14",
#         "description": "A philosophical exploration of the entire seven-book Harry Potter series Harry Potter has been heralded as one of the most popular book series of all time and the philosophical nature of Harry, Hermione, and Ron's quest to rid the world of its ultimate evil is one of the many things that make this series special. The Ultimate Harry Potter and Philosophy covers all seven titles in J.K. Rowling's groundbreaking series and takes fans back to Godric's Hollow to discuss life after death, to consider what moral reasoning drove Harry to choose death, and to debate whether Sirius Black is a man or a dog. With publication timed to coincide with the release of the movie Harry Potter and the Deathly Hallows (Part 1), this book will be the definitive guide for all fans looking to appreciate the series on a deeper level. Covers a range of intriguing topics such as the redemption of Severus Snape, the power of love, and destiny in the wizarding world Gives you a new perspective on Harry Potter characters, plot lines, and themes Makes a perfect companion to the Harry Potter books and movies Packed with interesting ideas and insights, The Ultimate Harry Potter and Philosophy is an ideal companion for anyone interested in unraveling the subtext and exploring the greater issues at work in the story.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_13",
#             "identifier": "9780470398258"
#           },
#           {
#             "type": "ISBN_10",
#             "identifier": "0470398256"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": true
#         },
#         "pageCount": 304,
#         "printType": "BOOK",
#         "categories": [
#           "Philosophy"
#         ],
#         "averageRating": 4.5,
#         "ratingsCount": 5,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "0.0.2.0.preview.1",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=lJB5DwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=lJB5DwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=lJB5DwAAQBAJ&printsec=frontcover&dq=intitle:Potter&hl=&cd=9&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=lJB5DwAAQBAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/The_Ultimate_Harry_Potter_and_Philosophy.html?hl=&id=lJB5DwAAQBAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.ch/books/download/The_Ultimate_Harry_Potter_and_Philosophy-sample-pdf.acsm?id=lJB5DwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=lJB5DwAAQBAJ&hl=&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "A philosophical exploration of the entire seven-book Harry Potter series Harry Potter has been heralded as one of the most popular book series of all time and the philosophical nature of Harry, Hermione, and Ron&#39;s quest to rid the world of ..."
#       }
#     },
#     {
#       "kind": "books#volume",
#       "id": "VYodjwEACAAJ",
#       "etag": "jiwAzoFK1bs",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/VYodjwEACAAJ",
#       "volumeInfo": {
#         "title": "Harry Potter und die Heiligtümer des Todes",
#         "authors": [
#           "Joanne K. Rowling"
#         ],
#         "publishedDate": "2011",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "3551354073"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9783551354075"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": false
#         },
#         "pageCount": 766,
#         "printType": "BOOK",
#         "categories": [
#           "Hogwarts School of Witchcraft and Wizardry (Imaginary organization)"
#         ],
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "preview-1.0.0",
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=VYodjwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=VYodjwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api"
#         },
#         "language": "de",
#         "previewLink": "http://books.google.ch/books?id=VYodjwEACAAJ&dq=intitle:Potter&hl=&cd=10&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=VYodjwEACAAJ&dq=intitle:Potter&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/Harry_Potter_und_die_Heiligt%C3%BCmer_des_To.html?hl=&id=VYodjwEACAAJ"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "NO_PAGES",
#         "embeddable": false,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": false
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=VYodjwEACAAJ&hl=&source=gbs_api",
#         "accessViewStatus": "NONE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "&quot;An eine Rückkehr nach Hogwarts ist für Harry nicht zu denken."
#       }
#     }
#   ]
# }

# %%
## test out your docstring here
print(request_books_api.__doc__)
# Out:
# Returns api-request from google books based on parameters given.

# %% [markdown]
# #### Useful knowledge: Status codes
#
# Responses contain information even without looking into the textual content. printing the response tells us the URL we requested, the date, its status, the content type and the size of the response object
#
# The most important for us is the status: it tells us whether our request has been successful: You can find a list of HTTP status codes here https://en.wikipedia.org/wiki/List_of_HTTP_status_codes.
# Or, you can always check HTTP Status Cats: https://www.flickr.com/photos/girliemac/sets/72157628409467125
#
# The most important status codes for us are:
#
# - successful call: code 200
# - client error: 4xx, e.g. 401: Unauthorized, 404: Not found
# - server error: 5xx, e.g. 500: Internal Server Error, 502: Bad Gateway

# %% [markdown]
# ### 2. Parsing json (40 points total)

# %% [markdown]
# **Exercise 2.1. (2 points)**
#
# Using the previously defined function, query the book with isbn number 1904633684 and print the text of the result.

# %%
aRequest=request_books_api(isbn="1904633684")
print(aRequest.text)
# Out:
# {
#   "kind": "books#volumes",
#   "totalItems": 1,
#   "items": [
#     {
#       "kind": "books#volume",
#       "id": "tBasGxqDMbMC",
#       "etag": "6yvUdKxPHY4",
#       "selfLink": "https://www.googleapis.com/books/v1/volumes/tBasGxqDMbMC",
#       "volumeInfo": {
#         "title": "The Case-book of Sherlock Holmes",
#         "authors": [
#           "Arthur Conan Doyle"
#         ],
#         "publisher": "Collector's Library",
#         "publishedDate": "2004",
#         "description": ".0000000000The Casebook of Sherlock Holmes contains Conan Doyle's last twelve stories about his great fictional detective. Compared with earlier collections these tales are darker, exploring such themes as treachery, mutilation and the terrible consequences of infidelity, and containing such gothic touches as a blood-sucking vampire and crypts at midnight. With an Afterword by David Stuart Davies, a Fellow of the Royal Literary Fund, and an authority on Sherlock Holmes. He has written the Afterwords for all the Collector's Library Holmes volumes.",
#         "industryIdentifiers": [
#           {
#             "type": "ISBN_10",
#             "identifier": "1904633684"
#           },
#           {
#             "type": "ISBN_13",
#             "identifier": "9781904633686"
#           }
#         ],
#         "readingModes": {
#           "text": false,
#           "image": true
#         },
#         "pageCount": 316,
#         "printType": "BOOK",
#         "categories": [
#           "Criminal investigation"
#         ],
#         "averageRating": 4.5,
#         "ratingsCount": 6,
#         "maturityRating": "NOT_MATURE",
#         "allowAnonLogging": false,
#         "contentVersion": "1.2.3.0.preview.1",
#         "panelizationSummary": {
#           "containsEpubBubbles": false,
#           "containsImageBubbles": false
#         },
#         "imageLinks": {
#           "smallThumbnail": "http://books.google.com/books/content?id=tBasGxqDMbMC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#           "thumbnail": "http://books.google.com/books/content?id=tBasGxqDMbMC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#         },
#         "language": "en",
#         "previewLink": "http://books.google.ch/books?id=tBasGxqDMbMC&printsec=frontcover&dq=isbn:1904633684&hl=&cd=1&source=gbs_api",
#         "infoLink": "http://books.google.ch/books?id=tBasGxqDMbMC&dq=isbn:1904633684&hl=&source=gbs_api",
#         "canonicalVolumeLink": "https://books.google.com/books/about/The_Case_book_of_Sherlock_Holmes.html?hl=&id=tBasGxqDMbMC"
#       },
#       "saleInfo": {
#         "country": "CH",
#         "saleability": "NOT_FOR_SALE",
#         "isEbook": false
#       },
#       "accessInfo": {
#         "country": "CH",
#         "viewability": "PARTIAL",
#         "embeddable": true,
#         "publicDomain": false,
#         "textToSpeechPermission": "ALLOWED",
#         "epub": {
#           "isAvailable": false
#         },
#         "pdf": {
#           "isAvailable": true,
#           "acsTokenLink": "http://books.google.ch/books/download/The_Case_book_of_Sherlock_Holmes-sample-pdf.acsm?id=tBasGxqDMbMC&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api"
#         },
#         "webReaderLink": "http://play.google.com/books/reader?id=tBasGxqDMbMC&hl=&source=gbs_api",
#         "accessViewStatus": "SAMPLE",
#         "quoteSharingAllowed": false
#       },
#       "searchInfo": {
#         "textSnippet": "Compared with earlier collections these tales are darker, exploring such themes as treachery, mutilation and the terrible consequences of infidelity, and containing such gothic touches as a blood-sucking vampire and crypts at midnight."
#       }
#     }
#   ]
# }

# %% [markdown]
# **Exercise 2.2. (2 points)**
#
# Now load the previous response into a json object.:

# %%
aJSON = aRequest.json()

# %% [markdown]
# **Exercise 2.3. (2 points)**
#
# What are the highest level keys of the json object?

# %%
keys=aJSON.keys()
print(keys)
# Out:
# dict_keys(['kind', 'totalItems', 'items'])

# %% [markdown]
# **Exercise 2.4. (1 point)**
#
# What is the type of the value of 'items' key?

# %%
print(type(aJSON["items"]))
# Out:
# <class 'list'>

# %% [markdown]
# **Exercise 2.5. (9 points)**
#
# Parse the following information from the json object

# %%
### Total number of items returned by the request
print(aJSON["totalItems"])

### Title of the book
print(aJSON["items"][0]["volumeInfo"]["title"])

### Authors of the book
print(aJSON["items"][0].get("volumeInfo").get("authors"))

### Date of publishing
print(aJSON["items"][0].get("volumeInfo").get("publishedDate"))

### Page Count
print(aJSON["items"][0].get("volumeInfo").get("pageCount"))

### Categories
print(aJSON["items"][0].get("volumeInfo").get("categories"))

### Average Rating
print(aJSON["items"][0].get("volumeInfo").get("averageRating"))

### Rating Count
print(aJSON["items"][0].get("volumeInfo").get("ratingsCount"))

### Is it avaliable as Epublication (Epub)
print(aJSON["items"][0].get("accessInfo").get("epub").get("isAvailable"))
# Out:
# 1
# The Case-book of Sherlock Holmes
# ['Arthur Conan Doyle']
# 2004
# 316
# ['Criminal investigation']
# 4.5
# 6
# False

# %% [markdown]
# **Exercise 2.6. (6 points)**
#
# Unlike in the case of requesting books by IDs, the requests in which you search for author or title usually have more than one book as a result. Try searching for books that contain a specific word in their title. Once you obtain the result of the request as a json object, loop through all books in the json and print out the **title** of all the books.

# %%
aRequest2=request_books_api(intitle="Stone")
bookList=aRequest2.json()
for book in bookList["items"]:
    print(book.get("volumeInfo").get("title"))
# Out:
# Dr. Stone 1
# Flesh and Stone: The Body and the City in Western Civilization
# Stick and Stone
# Silver, Sword, and Stone
# Art of Stone Painting
# The Wretched Stone
# Stone Soup
# The New Rolling Stone Album Guide
# Cutting for Stone
# Minoan Stone Vases

# %% [markdown]
# **Exercise 2.7. (9 points)**
#
# Now search for books by category and print out the authors

# %%
aRequest3=request_books_api(categories="Romance")
bookList2=aRequest3.json()
for book in bookList2["items"]:
    print(book.get("volumeInfo").get("authors"))
# Out:
# ['Kelsey Rodkey']
# ['Maeve Binchy']
# ['Tennessee Williams']
# ['Jude Deveraux']
# ['Catherine Bybee']
# ['Donna Clayton']
# ['Carolyn Keene']
# ['Francine Pascal', 'Kate William']
# ['Fern Michaels']
# ['Emma Darcy']

# %% [markdown]
# **Exercise 2.8. (9 points)**
#
# Define a function that given an item in the json object (the meta information about one book) returns a list with the following attributes: `title, authors, publishedDate, pageCount, categories, averageRating, ratingsCount, epub`.
# <br>
# Note that **not** every book has all the features required. If a piece of information is missing, your code should write NaN instead in place of the value.

# %%
def checkNaN(x):
    '''Checks if object x is of NoneType. Returns string "NaN" if true, the object x if false.'''
    if(x==None):
        return "NaN"
    return x

def parse_json(j):
    '''The function takes a book item as an input and returns a list of the extracted features.'''
    title=checkNaN(j.get("volumeInfo").get("title"))
    authors=checkNaN(j.get("volumeInfo").get("authors"))
    publishedDate=checkNaN(j.get("volumeInfo").get("publishedDate"))
    pageCount=checkNaN(j.get("volumeInfo").get("pageCount"))
    categories=checkNaN(j.get("volumeInfo").get("categories"))
    averageRating=checkNaN(j.get("volumeInfo").get("averageRating"))
    ratingsCount=checkNaN(j.get("volumeInfo").get("ratingsCount"))
    epub=checkNaN(j.get("accessInfo").get("epub").get("isAvailable"))

    return title, authors, publishedDate, pageCount, categories, averageRating, ratingsCount, epub


aRequest4=request_books_api(intitle="Harry Potter").json()
#Returns the values of the first book, with the variables having values.
print(parse_json(aRequest4["items"][0]))
#Returns the values of the second book, with some of the variables not having a value.
print(parse_json(aRequest4["items"][1]))
# Out:
# ('Harry Potter und der Stein der Weisen', ['Joanne K. Rowling'], '1998', 346, ["Children's literature, English"], 5, 2, False)
# ('Harry Potter 1 und der Stein der Weisen. Schmuckausgabe', ['Joanne K. Rowling'], '2015-10-06', 245, ['Juvenile Fiction'], 'NaN', 'NaN', False)

# %% [markdown]
# ### 3. New York Times API (40 points total)
#
# Your task in this exercise will be to compare the amount of Chatbot, NFT, Corona, NATO related articles in the last 12 months, using an API that the New York Times provides.
#
# Start with creating an API key on the NYT API website. As you can see there are multiple functionalities/APIs that the NYT provides. For this exercise we will use the one that allows you to search among articles. so when you sign up for the API key, make sure to pick that one.
#
# Here's the documentation for using this API, it explains the syntacs of queries: https://developer.nytimes.com/docs/articlesearch-product/1/overview
#
# **Exercise 3.1. (2 points)**
#
# How can you specify a keyword to search for in the URL?

# %%
## /articlesearch.json?q=KEYWORD
print(requests.get("https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=dStQ04EXmMRGkeBAGsWjGACwZI4gLN1I").text)
# Out:
# {"status":"OK","copyright":"Copyright (c) 2023 The New York Times Company. All Rights Reserved.","response":{"docs":[{"abstract":"Peter Obi was until recently a secondary player in Nigerian politics. By switching parties and appealing to the digitally savvy, he overturned the old order.","web_url":"https://www.nytimes.com/2023/02/28/world/africa/peter-obi-nigeria-election.html","snippet":"Peter Obi was until recently a secondary player in Nigerian politics. By switching parties and appealing to the digitally savvy, he overturned the old order.","lead_paragraph":"Nine months ago, Peter Obi was a member of Nigeria’s main opposition party, the People’s Democratic Party, and one of the 15 presidential aspirants cleared for its ticket. As a former state governor, he stood solidly in the ranks of the political establishment.","source":"The New York Times","multimedia":[{"rank":0,"subtype":"xlarge","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-articleLarge.jpg","height":400,"width":600,"legacy":{"xlarge":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-articleLarge.jpg","xlargewidth":600,"xlargeheight":400},"subType":"xlarge","crop_name":"articleLarge"},{"rank":0,"subtype":"popup","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-popup.jpg","height":433,"width":650,"legacy":{},"subType":"popup","crop_name":"popup"},{"rank":0,"subtype":"blog480","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-blog480.jpg","height":320,"width":480,"legacy":{},"subType":"blog480","crop_name":"blog480"},{"rank":0,"subtype":"blog533","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-blog533.jpg","height":355,"width":533,"legacy":{},"subType":"blog533","crop_name":"blog533"},{"rank":0,"subtype":"blog427","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-blog427.jpg","height":285,"width":427,"legacy":{},"subType":"blog427","crop_name":"blog427"},{"rank":0,"subtype":"tmagSF","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-tmagSF.jpg","height":241,"width":362,"legacy":{},"subType":"tmagSF","crop_name":"tmagSF"},{"rank":0,"subtype":"tmagArticle","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-tmagArticle.jpg","height":395,"width":592,"legacy":{},"subType":"tmagArticle","crop_name":"tmagArticle"},{"rank":0,"subtype":"slide","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-slide.jpg","height":400,"width":600,"legacy":{},"subType":"slide","crop_name":"slide"},{"rank":0,"subtype":"jumbo","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-jumbo.jpg","height":683,"width":1024,"legacy":{},"subType":"jumbo","crop_name":"jumbo"},{"rank":0,"subtype":"superJumbo","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-superJumbo.jpg","height":1365,"width":2048,"legacy":{},"subType":"superJumbo","crop_name":"superJumbo"},{"rank":0,"subtype":"blog225","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-blog225.jpg","height":150,"width":225,"legacy":{},"subType":"blog225","crop_name":"blog225"},{"rank":0,"subtype":"master1050","caption":null,"credit":null,"type":"image","url":"images/2023/02/27/multimedia/00nigeria-obi-1-bmpv/00nigeria-obi-1-bmpv-master1050.jpg","height":700,"width":1050,"legacy":{},"subType":"master1050","crop_name":"master1050"},{"rank":0,"subtype":"mast ...

# %% [markdown]
# **Exercise 3.2. (4 points)**
#
# How can you specify a date or multiple dates to search for?

# %%
## for a date range: begin_date=20220316&end_date=20220317
## for specific dates: fq=pub_date:(2022-03-16 OR 2022-03-17)
print(requests.get("https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&begin_date=20220316&end_date=20220317&api-key=dStQ04EXmMRGkeBAGsWjGACwZI4gLN1I").text)
print(requests.get("https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&fq=pub_date:(2022-03-16%20OR%202022-03-17)&api-key=dStQ04EXmMRGkeBAGsWjGACwZI4gLN1I").text)
# Out:
# {"status":"OK","copyright":"Copyright (c) 2023 The New York Times Company. All Rights Reserved.","response":{"docs":[{"abstract":"Years ago, voters created a commission to make political maps fairer. Now the State Supreme Court is blocking maps drawn by the Republican-led commission, saying nothing has changed.","web_url":"https://www.nytimes.com/2022/03/17/us/politics/ohio-court-congress-maps.html","snippet":"Years ago, voters created a commission to make political maps fairer. Now the State Supreme Court is blocking maps drawn by the Republican-led commission, saying nothing has changed.","lead_paragraph":"A bipartisan majority of Ohio Supreme Court justices has ratcheted up an extraordinary legal standoff over the state’s political boundaries, rejecting — for the third time in barely two months — new maps of state legislative districts that heavily favor the Republican Party.","print_section":"A","print_page":"15","source":"The New York Times","multimedia":[{"rank":0,"subtype":"xlarge","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-articleLarge.jpg","height":403,"width":600,"legacy":{"xlarge":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-articleLarge.jpg","xlargewidth":600,"xlargeheight":403},"subType":"xlarge","crop_name":"articleLarge"},{"rank":0,"subtype":"popup","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-popup.jpg","height":437,"width":650,"legacy":{},"subType":"popup","crop_name":"popup"},{"rank":0,"subtype":"blog480","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-blog480.jpg","height":323,"width":480,"legacy":{},"subType":"blog480","crop_name":"blog480"},{"rank":0,"subtype":"blog533","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-blog533.jpg","height":358,"width":533,"legacy":{},"subType":"blog533","crop_name":"blog533"},{"rank":0,"subtype":"blog427","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-blog427.jpg","height":287,"width":427,"legacy":{},"subType":"blog427","crop_name":"blog427"},{"rank":0,"subtype":"tmagSF","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-tmagSF.jpg","height":243,"width":362,"legacy":{},"subType":"tmagSF","crop_name":"tmagSF"},{"rank":0,"subtype":"tmagArticle","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-tmagArticle.jpg","height":398,"width":592,"legacy":{},"subType":"tmagArticle","crop_name":"tmagArticle"},{"rank":0,"subtype":"slide","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-slide.jpg","height":403,"width":600,"legacy":{},"subType":"slide","crop_name":"slide"},{"rank":0,"subtype":"jumbo","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-jumbo.jpg","height":689,"width":1024,"legacy":{},"subType":"jumbo","crop_name":"jumbo"},{"rank":0,"subtype":"superJumbo","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-superJumbo.jpg","height":1377,"width":2048,"legacy":{},"subType":"superJumbo","crop_name":"superJumbo"},{"rank":0,"subtype":"blog225","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-blog225.jpg","height":151,"width":225,"legacy":{},"subType":"blog225","crop_name":"blog225"},{"rank":0,"subtype":"master1050","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-master1050.jpg","height":706,"width":1050,"legacy":{},"subType":"master1050","crop_name":"master1050"},{"rank":0,"subtype":"master675","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-master675.jpg","height":454,"width":67 ...
# {"status":"OK","copyright":"Copyright (c) 2023 The New York Times Company. All Rights Reserved.","response":{"docs":[{"abstract":"Years ago, voters created a commission to make political maps fairer. Now the State Supreme Court is blocking maps drawn by the Republican-led commission, saying nothing has changed.","web_url":"https://www.nytimes.com/2022/03/17/us/politics/ohio-court-congress-maps.html","snippet":"Years ago, voters created a commission to make political maps fairer. Now the State Supreme Court is blocking maps drawn by the Republican-led commission, saying nothing has changed.","lead_paragraph":"A bipartisan majority of Ohio Supreme Court justices has ratcheted up an extraordinary legal standoff over the state’s political boundaries, rejecting — for the third time in barely two months — new maps of state legislative districts that heavily favor the Republican Party.","print_section":"A","print_page":"15","source":"The New York Times","multimedia":[{"rank":0,"subtype":"xlarge","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-articleLarge.jpg","height":403,"width":600,"legacy":{"xlarge":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-articleLarge.jpg","xlargewidth":600,"xlargeheight":403},"subType":"xlarge","crop_name":"articleLarge"},{"rank":0,"subtype":"popup","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-popup.jpg","height":437,"width":650,"legacy":{},"subType":"popup","crop_name":"popup"},{"rank":0,"subtype":"blog480","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-blog480.jpg","height":323,"width":480,"legacy":{},"subType":"blog480","crop_name":"blog480"},{"rank":0,"subtype":"blog533","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-blog533.jpg","height":358,"width":533,"legacy":{},"subType":"blog533","crop_name":"blog533"},{"rank":0,"subtype":"blog427","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-blog427.jpg","height":287,"width":427,"legacy":{},"subType":"blog427","crop_name":"blog427"},{"rank":0,"subtype":"tmagSF","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-tmagSF.jpg","height":243,"width":362,"legacy":{},"subType":"tmagSF","crop_name":"tmagSF"},{"rank":0,"subtype":"tmagArticle","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-tmagArticle.jpg","height":398,"width":592,"legacy":{},"subType":"tmagArticle","crop_name":"tmagArticle"},{"rank":0,"subtype":"slide","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-slide.jpg","height":403,"width":600,"legacy":{},"subType":"slide","crop_name":"slide"},{"rank":0,"subtype":"jumbo","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-jumbo.jpg","height":689,"width":1024,"legacy":{},"subType":"jumbo","crop_name":"jumbo"},{"rank":0,"subtype":"superJumbo","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-superJumbo.jpg","height":1377,"width":2048,"legacy":{},"subType":"superJumbo","crop_name":"superJumbo"},{"rank":0,"subtype":"blog225","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-blog225.jpg","height":151,"width":225,"legacy":{},"subType":"blog225","crop_name":"blog225"},{"rank":0,"subtype":"master1050","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-master1050.jpg","height":706,"width":1050,"legacy":{},"subType":"master1050","crop_name":"master1050"},{"rank":0,"subtype":"master675","caption":null,"credit":null,"type":"image","url":"images/2022/03/17/us/politics/17ohio-map/17ohio-map-master675.jpg","height":454,"width":67 ...

# %% [markdown]
# **Exercise 3.3. (4 points)**
#
# Write a function that takes a search term, and two dates as an input, and returns a correct search query you can use for an API as an output

# %%
def getNYT (term,date1,date2):
    baseLink="https://api.nytimes.com/svc/search/v2/articlesearch.json?"
    link=baseLink+"q="+term+"&fq=pub_date:("+date1+"%20OR%20"+date2+")&api-key=dStQ04EXmMRGkeBAGsWjGACwZI4gLN1I"
    aRequest=requests.get(link)
    return(aRequest)

print(getNYT("election","2022-02-28","2022-02-27").text)
# Out:
# {"status":"OK","copyright":"Copyright (c) 2023 The New York Times Company. All Rights Reserved.","response":{"docs":[{"abstract":"William P. Barr’s memoir of his time as attorney general under George H.W. Bush and then again under Donald J. Trump defends his more recent leadership of the Justice Department.","web_url":"https://www.nytimes.com/2022/02/27/us/politics/bill-barr-trump-january-6.html","snippet":"William P. Barr’s memoir of his time as attorney general under George H.W. Bush and then again under Donald J. Trump defends his more recent leadership of the Justice Department.","lead_paragraph":"WASHINGTON — Former Attorney General William P. Barr writes in a new memoir that former President Donald J. Trump’s “self-indulgence and lack of self-control” cost him the 2020 election and says “the absurd lengths to which he took his ‘stolen election’ claim led to the rioting on Capitol Hill.”","print_section":"A","print_page":"17","source":"The New York Times","multimedia":[{"rank":0,"subtype":"xlarge","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-articleLarge.jpg","height":400,"width":600,"legacy":{"xlarge":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-articleLarge.jpg","xlargewidth":600,"xlargeheight":400},"subType":"xlarge","crop_name":"articleLarge"},{"rank":0,"subtype":"popup","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-popup.jpg","height":433,"width":650,"legacy":{},"subType":"popup","crop_name":"popup"},{"rank":0,"subtype":"blog480","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-blog480.jpg","height":320,"width":480,"legacy":{},"subType":"blog480","crop_name":"blog480"},{"rank":0,"subtype":"blog533","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-blog533.jpg","height":355,"width":533,"legacy":{},"subType":"blog533","crop_name":"blog533"},{"rank":0,"subtype":"blog427","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-blog427.jpg","height":285,"width":427,"legacy":{},"subType":"blog427","crop_name":"blog427"},{"rank":0,"subtype":"tmagSF","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-tmagSF.jpg","height":241,"width":362,"legacy":{},"subType":"tmagSF","crop_name":"tmagSF"},{"rank":0,"subtype":"tmagArticle","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-tmagArticle.jpg","height":395,"width":592,"legacy":{},"subType":"tmagArticle","crop_name":"tmagArticle"},{"rank":0,"subtype":"slide","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-slide.jpg","height":400,"width":600,"legacy":{},"subType":"slide","crop_name":"slide"},{"rank":0,"subtype":"jumbo","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-jumbo.jpg","height":683,"width":1024,"legacy":{},"subType":"jumbo","crop_name":"jumbo"},{"rank":0,"subtype":"superJumbo","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-superJumbo.jpg","height":1365,"width":2048,"legacy":{},"subType":"superJumbo","crop_name":"superJumbo"},{"rank":0,"subtype":"blog225","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-blog225.jpg","height":150,"width":225,"legacy":{},"subType":"blog225","crop_name":"blog225"},{"rank":0,"subtype":"master1050","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Barr-01/27dc-Barr-01-master1050.jpg","height":700,"width":1050,"legacy":{},"subType":"master1050","crop_name":"master1050"},{"rank":0,"subtype":"master675","caption":null,"credit":null,"type":"image","url":"images/2022/02/27/multimedia/27dc-Bar ...

# %% [markdown]
# **Exercise 3.4. (20 points)**
#
# Write a function that takes a query to the API as an input and returns the number of hits (number of article results) that this query returns. Make sure that you are getting the total number of articles for the time period. Use this function to collect the number of hits for each search term we are interested in (Chatbot, NFT, Corona, NATO) for each time periods of interest.
#
# Hint: Function suddenly returning 0? You might need to delay the queries you are making to the API. You could use time.sleep() function.

# %%
def getAmountNYT(term,startdate,enddate):
    baseLink="https://api.nytimes.com/svc/search/v2/articlesearch.json?"
    link=baseLink+"q="+term+"&begin_date="+startdate+"&end_date="+enddate+"&api-key=dStQ04EXmMRGkeBAGsWjGACwZI4gLN1I"
    aRequest=requests.get(link).json()
    #Catch error responses
    try:
        return(aRequest["response"]["meta"]["hits"])
    except:
        print("Error response! "+aRequest["fault"]["faultstring"])
        return(None)

# %%
print(getAmountNYT("Chatbot","20220317","20230316"))
print(getAmountNYT("NFT","20220317","20230316"))
print(getAmountNYT("Corona","20220317","20230316"))
print(getAmountNYT("NATO","20220317","20230316"))
# Out:
# 202
# 179
# 116
# 1290

# %% [markdown]
# **Exercise 3.5. (10 points)**
#
# Remember, that our original question was how the appearance of 4 topics changed over time in the last 6 months. Now we have all the pieces to do this - some written by you, plus the visualisation code provided by us below. Visualise the change in the number of articles over the last 6 months. Then, write a short text interpreting the graph - what trends do you see? What could be reasons for these trends?

# %%
import time

# takes around 2min30sec

def try_req(topic, sDate, eDate):
    for delay in [5, 20, 60]:
        time.sleep(delay)
        try:
            return getAmountNYT(topic, sDate, eDate)
        except:
            pass
    return 0

CBSep = try_req("Chatbot","20220901","20220930")
CBOct = try_req("Chatbot","20221001","20221031")
CBNov = try_req("Chatbot","20221101","20221130")
CBDez = try_req("Chatbot","20221201","20221231")
CBJan = try_req("Chatbot","20230101","20230131")
CBFeb = try_req("Chatbot","20230201","20230228")

NFTSep = try_req("NFT","20220901","20220930")
NFTOct = try_req("NFT","20221001","20221031")
NFTNov = try_req("NFT","20221101","20221130")
NFTDez = try_req("NFT","20221201","20221231")
NFTJan = try_req("NFT","20230101","20230131")
NFTFeb = try_req("NFT","20230201","20230228")

CoSep = try_req("Corona","20220901","20220930")
CoOct = try_req("Corona","20221001","20221031")
CoNov = try_req("Corona","20221101","20221130")
CoDez = try_req("Corona","20221201","20221231")
CoJan = try_req("Corona","20230101","20230131")
CoFeb = try_req("Corona","20230201","20230228")

NaSep = try_req("NATO","20220901","20220930")
NaOct = try_req("NATO","20221001","20221031")
NaNov = try_req("NATO","20221101","20221130")
NaDez = try_req("NATO","20221201","20221231")
NaJan = try_req("NATO","20230101","20230131")
NaFeb = try_req("NATO","20230201","20230228")


dict_results2 = {'Chatbot':[CBSep, CBOct, CBNov, CBDez, CBJan, CBFeb],
                 'NFT':[NFTSep, NFTOct, NFTNov, NFTDez, NFTJan, NFTFeb],
                 'Corona':[CoSep, CoOct, CoNov, CoDez, CoJan, CoFeb],
                 'NATO':[NaSep, NaOct, NaNov, NaDez, NaJan, NaFeb]
                }

# %%
# Chatbot: The appearance of Chatbot increased substantially, especially in the past 3 months.
    # This might be mostly due to the new chatbots like ChatGPT which got a lot of attention.
    
# NFT: The appearance of NFT was rather constant during the last 6 month, without a clear trend.

# Corona: The appearance of Corona was rather constant during the last 6 months, without a clear thrend, 
    # but a slight peak in december which could be related to increased relevance due to christmas season.
    
# Nato: The appearance of Nato was very high in general during the last 6 months, compared to the other 3 terms.
    # There was a slight trend of increasing over the past 6 months, 
    # leading to peaks close to 100 in the last 2 months.

# %% [markdown]
# #### Visualization
#
# To help you out with the visualization, we have created the code below. In the description of the function you can find instructions on how to use it. There is also an example of a call underneath the function.
#
# You need to give two parameters to the function. The first one is a dictionary where the keys are the three search query terms that you have used (given as a string); for each term there is one list with the number of queries per each time-block considered. The second parameter is a list of strings with the names of the time periods being considered.
#
# Important note: the lengths of the lists must match. It is assumed that for each query there is a vector having the number of hits per each period specified in the list of the second parameter. This means that the three lists in the dictionary and the list given as the second parameter must have equal lengths.

# %%
# This is a pre-implemented function for crating the visualisation
# You don't have to modify this

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

def plot_no_articles(dictionary_results, periods):
    '''
    Plots the statistics with the number of articles in the past month.
    
    dictionary_results = dictionary of the form query_term: [no_articles_for_period_1, no_articles_for_period_2, ...]
        e.g. {'Brexit':[250, 200], 'Trump':[100, 75], 'Corona':[300, 400]}
             if you group articles by month periods, and 
             you have looked only at the past two months, and
             there were 250 hits for Brexit in February, and 200 in March, and
             there were 100 hits for Trump in February, and 75 in March, and
             there were 300 hits for Corona in February, and 400 in March
    periods = list of time periods used for the investigation
        e.g. ['February', 'March']
             if you have considered the past two months
    '''
    d = dictionary_results
    labels = periods
    query_terms = list(d.keys())
    list_0 = d[query_terms[0]]
    list_1 = d[query_terms[1]]
    list_2 = d[query_terms[2]]
    list_3 = d[query_terms[3]]
    
    # locations for labels
    x = np.arange(0, len(labels))
    # width per bar
    width = 0.2
    
    # Building the subplots
    fig, ax = plt.subplots(figsize=(18,10))
    rects1 = ax.bar(x - width, list_0, width, label=query_terms[0])
    rects2 = ax.bar(x, list_1, width, label=query_terms[1])
    rects3 = ax.bar(x + width, list_2, width, label=query_terms[2])
    rects4 = ax.bar(x + 2*width, list_3, width, label=query_terms[3])

    # Labeling
    ax.set_xlabel('Time periods')
    ax.set_ylabel('Number of articles')
    ax.set_title('Number of articles by query')
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.autoscale()
    xmin = -2*width
    xmax = max(np.arange(len(labels)))+3*width
    ymin = 0
    ymax = max(list_0+list_1+list_2+list_3)*1.1 
    ax.set(xlim=(xmin, xmax), ylim=(ymin, ymax))
    ax.legend(loc='best')


    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() /2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')


    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)
    autolabel(rects4)
    
    fig.autofmt_xdate()

    fig.tight_layout()

    plt.show()

# Below there is one example of how to use the above plot function
#dict_results2 = {'Chatbot':[250, 200], 'NFT':[100, 75], 'Corona':[300, 400], 'NATO':[50, 340]}
#plot_no_articles(dict_results2, ['February', 'March'])
print(dict_results2)
plot_no_articles(dict_results2, ['September', 'October', 'November', 'December', 'January', 'February'])
# Out:
# {'Chatbot': [3, 1, 0, 25, 42, 81], 'NFT': [8, 12, 10, 13, 5, 9], 'Corona': [5, 8, 11, 20, 13, 7], 'NATO': [74, 85, 68, 68, 96, 98]}
